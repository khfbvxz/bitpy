# %%
'''1장 문자 출력'''
'''
print("aa")          "" 큰 따옴표로 둘러 싸면 문자열 됨
print("aa" + "bb")  + 문자열 더해진 것 처럼 출력
print("aa"  *20)    * 숫자만큼 출력
print("100" + "200") 문자열 100200
print(100 + 300)      숫자  300 


'''

# %%
'''터틀 그래픽 모듈'''
'''
https://blog.daum.net/sualchi/13720353 터틀 함수 모음 블로그 
import turtle
t = turtle.Turtle()
title(“창 이름”)      # 그래픽 창 이름을 지정
reset()                      # 터틀 초기화 & 화면 지움
clear()                      # 화면 지움 (거북이 이동 없음)
home()                # 초기 위치로 이동
goto(300, 300)      # 위치 이동 (= setpos(), setposition())
setx(x)                # x 위치로 이동 (가운데는 0)
sety(y)                # y 위치로 이동 (가운데는 0)
speed(0)             # 거북이 속도 (0: 최고, 1:느림, 10: 빠름)
position()            # 현재 위치 얻기 (= pos())
xcor()                 # 거북이 x 위치 구함
ycor()                 # 거북이 y 위치 구함
heading              # 거북이가 바라보는 각도(이동 방향) 구함
distance(x, y)      # 지정한 위치까지의 거리 구함
toward(x, y)        # 현재 위치에서 지정한 위치를 바라보는 각도 구함
penup()              # 펜 내리기 (= pu(), up()). 이동하면 그리기 작동
pendown()          # 펜 올리기 (= pd(), down()). 이동할 때 그리기 안함
isdown()             # 펜이 내려진 상태인가
color('red')         # 펜 색 지정하기
                          (색 문자열은 대소문자 상관없음. 'Red', 'RED', 'red')
fillcolor('blue')    # 도형을 채우는 색 지정하기
begin_fill()          # 도형 채우기 준비
end_fill()            # 도형 채우기 종료
write(arg, move=False, align=“left”, font=(“Arial”, 10, “normal”))
                        # 문자열 출력. move는 글자 출력 후 이동 여부 
                               (예) turtle.write(“안녕?”, False, “center”, ("", 12,""))
                          # 가운데 정렬 방식으로 크기 12로 출력
                       (예) turtle.write(“안녕?”, font=("", 12,""))   
showturtle()        # 거북이를 표시 (= st())
hideturtle()         # 거북이를 숨김 (= ht())
isvisible()            # 거북이가 보이는 상태인가?
shape(“모양”)      # 거북이 모양 변경
                        ('classic'(기본), 'circle', 'square', 'triangle', 'arrow', 'turtle')
listen()               # 사용자 입력을 위한 포커스 강조
onkeypress(함수, “키”)    # 키를 누를 때 실행할 함수 지정
                         ('Left', 'Right', 'Up', 'Down', 'a', 'b', 'c', ...)
onclick(함수)       # 마우스 클릭 시 실행할 함수 지정 (= onscreenclick())
ontimer(함수, 시간) # 일정 시간(1/1000초 단위, ms) 지난 후 실행할 함수 지정
forward(100)         # 보는 방향으로 100 픽셀 이동 (= fd(100))
backward(100)      # 반대 방향으로 100 픽셀 이동 (= bk(100), back(100))
left(90)               # 왼쪽으로 90도 돌기 (= lt(90))
right(90)             # 오른쪽으로 90도 돌기 (= rt(90))
setheading(각도)    # 보는 방향 변경 (= seth(각도))
circle(반지름)      # 원 그리기
turtle.bgcolor("색상")     # 배경색 설정

t.pencolor(colors[length%6]) 색 반복할때 colors[length%6]!!

# %%
t.pencolor(colors[length%6]) 색 반복할때 colors[length%6]!! 중요
s = turtle.Screen()  
s.mainloop()     터틀 그래픽 창 안꺼지게

# %%
'''2장 변수 입력 받기'''
name = input("이름 : ")  # 문자열 입력 받기
x = int(input("수를 입력하세요")) # 수 입력받기 int 정수형 float 실수형

# %%
'''3장 파이썬 연산자 예제''' 
a = 15          # 대입(할당) 연산자
b = 4           # 대입(할당) 연산자
print('-'*50)
# 사칙연산 및 나누기, 승
print(a + b)    # 더하기
print(a - b)    # 빼기
print(a * b)    # 곱하기
print(a / b)    # 나누기 (소수점 이하도 계산)     실수 나눗셈
print(a // b)   # 정수 나누기 (소수점 이하 버림)  정수 몫 
print(a % b)   # a 나누기 b의 나머지
print(a ** b)   # a의 b승 지수  **0.5 루트 
print('-'*50)
# 복합 대입 연산자
+=
-=
*=
/=
//=
%=

# Bit 단위 연산자
print(a ^ b)    # bit XOR
print(a & b)    # bit AND
print(a | b)    # bit OR
print(~a)       # bit 보수 (Complement)
print(~b)       # bit 보수 (Complement)
print(a >> b)   # bit right-shift
print(a << b)   # bit left-shift
print('-'*50)
data = [1,2,3,4,5]    

# 집합형(컴테이너)에 포함되어 있는지 검사
print( b in data )      # 멤버 연산자 (포함되어 있는가?)
print( b not in data)   # 멤버 연산자 (포함되지 않았는가?)
print('-'*50)

# 동일한 개체인지 검사
print ( a is b )    # 같은 개체인가 (Identity) : 값 비교가 아님 
print('-'*50)

# 값 비교 
print ( a == b )    # a, b 값이 같은가
print ( a != b )    # a, b 값이 다른가
print ( a >= b )    # a가 크거나 같은가
print ( a <= b )    # a가 작거나 같은가
print ( a > b )     # a가 큰가
print ( a < b )     # a가 작은가
print('-'*50)

# %%
'''4장 자료의 종류'''
int    정수형   int( )
float  실수형   float( )
str    문자열   str( )  숫자 문자열로 
문자들의 나열 '' 작은 따옴표 "" 큰따옴표
"나의 책 이름 '개미' " 구분 할때 
'Hello'+'World'  출력 'HelloWorld'
num = '980'
print(num)              # 980  : 문자열 '980'을 출력 
print(int(num))          # 980  : 문자열 '980'을 정수로 변환하여 출력
print(str(int(num)))    # 980   : 문자열 '980'을 정수로 바꿨다가 다시 문자열로 바꿔 출력
print(float(num))       # 980.0 : 문자열 '980'을 부동소수점수로 바꿔서 출력
print(str(float(num)))   # 980.0 : 문자열 '980'을 부동소수점수로 바꿨다가 다시 문자열로 출력
print(int(float(num)))   # 980  : 문자열 '980'을 부동수소점수로 바꿨다가 다시 정수로 출력 


price =10000
print("싱품의 가격 %s 원 입니다."% price)  문자열 사이에 변수의 값 출력
\n  줄바꿈 개행문자 

# 문자열 다루는 예제
s = "홍길동은 19살"

# 문자열을 전체 또는 일부분 다루기 
print(s)                # 홍길동은 19살
print(s[0])             # 홍
print(s[0]+s[1]+s[2])   # 홍길동
print(s[0:3])           # 홍길동
print(s[:3])            # 홍길동
print(s[5]+s[6])        # 19
print(s[5:7])           # 19
print(s[5:])            # 19살
print(s[-1])            # 살
print(s[-3]+s[-2]+s[-1])# 19살


# 문자열을 튜플처럼 값을 변경하지 못함

# 다음처럼 새 문자열로 구성하여 다시 할당해야 함
s = s[:5] + '20' + s[-1]
print(s)                # 홍길동은 20살

# replace 함수를 이용해도 대치할 수 있습니다.
print(s.replace('20', '30'))   # 홍길동은 30살
print(s.replace('30', '20'))   # 홍길동은 20살
s = "김철수는" + s[4:]
print(s)                # 김철수는 20살


# 문자열 길이 
print("문자열 길이는 " + str(len(s))) # 문자열 길이는8
print("문자열 길이는 %d" %len(s))     # 문자열 길이는8

# 몇 개 존재하는가 
print(s.count('2'))     # 1 : s에 '2'가 나온 횟수
print(s.count('20'))    # 1 : s에 '20'이 나온 횟수


# 결합
꼬리 = "입니다."
print(s + 꼬리)         # 김철수는 20살입니다.


# 리스트를 문자열로 변환하기
리스트 = ['김철수는', ' ', '20', '살', '입니다.']
print(리스트)          # ['김철수는', ' ', '20', '살', '입니다.']
print(str(리스트))     # ['김철수는', ' ', '20', '살', '입니다.']
print(''.join(리스트)) # 김철수는 20살입니다.

# 문자열 내부 검색
print(s.find('20'))     # 5: 인덱스 5번 위치에 있음 
print(s.find('a'))      # -1: 찾지 못함


# 문자열을 분리 문자를 넣어서 구분하기
print(','.join(s))      # 김,철,수,는, ,2,0,살

# 문자열을 분리하여 리스트로 만들기 (아래는 공백 기준으로 분리)
print(s.split())        # ['김철수는', '20살']
# 참고로 문자열 객체는 find, count 하수 이외에도등 문자열 처리를 지원하는
# 많은 함수 및 포매팅 기능을 지원합니다.

# %%
'''5장 조건 if '''
'''
if 조건식1 : 
    조건식1 참일떄 수행될 문장
elif 조건식2 : 
    조건식2 참일떄 수행될 문장
else : 
    참이 아닐떄 
'''
논리 연산자 
x and y
x or y
not x 
# 값 비교 
print ( a == b )    # a, b 값이 같은가
print ( a != b )    # a, b 값이 다른가
print ( a >= b )    # a가 크거나 같은가
print ( a <= b )    # a가 작거나 같은가
print ( a > b )     # a가 큰가
print ( a < b )     # a가 작은가
print('-'*50)

# %%
''' 6 장 반복 '''

for 변수 in range(종료값) 5번 반복  range(start,stop, step )
    문장                             종료값 stop 은 포함 안됨 +1 하거나 -1 고려
    print(i, end=" ") end 는 줄바꿈 안되게 하는 함수

while 조건:    조건 참이면 반복
    반복 문장

무한 루프  종료조건 생각
sign = True
while sign:
    light = input("신호등 색상을 입력하시오: ")
    if light=='blue':
        sign = False
print("전진")

''' break continue'''
while True:
    light = input("신호등 색상을 입력하시오: ")
    if light=='blue':
        break     강제로 반복 중지
print("전진")


for n in range(10):
    if n % 2 ==0:
        continue    해당 차례 건너 뛰고 새롭게 다음 차례 반복을 수행
    print(n)

# %%
'''7장 리스트'''
slist=['영어','수학','사회','과학' 
인덱스는 0번 부터
슬라이싱 : 여러 개의 항목을 추출하는 기법
letters=['A','B','C','D','E','F']
print(letters[0:3])  0~2
print(letters[:3])   처음부터 2까지
print(letters[3:])   index 3부터 끝까기
print(letters[:])    전체
copy=letters[:]
print(copy)

'''리스트 추가 '''
cart=[]
cart.append("사과")   리스트 추가는 ,append()
cart.append("세제")   추가하면 index 끝에 저장됨
print(cart)
cart.insert(1,'건전지') 인덱스 위치에 추가 .insert(인덱스 위치, 내용)

'''리스트 제거'''
.remove("내용")
del 리스트명[index] 
.pop()  맨 끝 index 제거
       
'''리스트 항목 탐색'''
,index("내용")   출력 dlseprtm qjsgh
cart=['사과','세제','화장지','치약']    
if '화장지' in cart:
    print(cart.index('화장지'))

'''리스트 정렬 '''
정렬 (sorting)
.sort()              오름차순 정렬
.sort(reverse = True) 내림차순 정렬
정렬된 새로운 리스트가 필요하면
sorted(리스트명) 

'''2차원 리스트 2차원 배열'''
num = [[10,20,30],[40,50,60]]

# %%
'''8장 함수 '''

def 함수명 ( 매개변수 ): 
    수행할 명령1
    수행할 명령2
''' 기본 매개변수 '''
def inc(a,step=1):  #인수를 넘겨주지 않아도인수가 자신의 기본값을 갖도록
    print(a+step)
inc(10)
inc(10,50)

'''반환 return 반환값 사용 안할 수도 있음''' 
def calculate_area(radius):    # 함수의 정의
    area=3.14*radius**2
    return area         # 함숫 값의 반환  

c_area = cal_area(5.0)   #함수의 호출
print(c_area)
area_sum=cal_area(5.0)+cal_area(10.0) # 수식에 적용된 함수 호출                  
print(area_sum)

def get_input():  #파이썬 반환값 여러 개 가능
    return 2,3 
x,y=get_input()
print(x,",",y)

'''
지역변수 함수 내애세만
전역변수 전체 프로그램
'''
result = 0     # 전역변수 
def calculate_area(radius): 
    global result  #함수 안 계산된 값을 전역변수에 저장
    result=3.14*radius**2  # 지역변수
          
r = float(input("반지름"))
calculate_area()
print(result)

'''디폴트 인수 기본값으로 매개변수를 처리해주는 장치'''
def greet(name, msg = "잘 지내죠?"):
    print ('안녕'+name+','+msg)
greet("철수", "좋은아침!")
greet("영희")

'''
위치인수    인수를 위치에 의해 구분
키워드 인수 인우 앞의 키워드에 따라 구분
'''
def func1(x,y,z):
    return x*y*z
func1(1,3,5)          # 15
func1(y=7,z=5,x=2)    # 70
func1(z=2,x=4,y=5)    # 40
func1(5,x=4,y=5)      # 100
func1z=10,20,x=2)     # 에러 위치인수가 키워드 인수 뒤에 오면 x
func1(5,x=2,z=20)     # 에러 (x 에 두개의 값이 중복으로 할당
# Out:
#   File "<ipython-input-10-adb192a945ea>", line 4
#     수행할 명령1
#         ^
# SyntaxError: invalid syntax

# %%
'''9장 딕셔너리 '''
'''
딕셔너리 명 = { 키 : value , 키2 : value2, 키3 : value3  }
 하나씩 매핑
'''
book = {}             # book = {"길동":"1234"}
book["길동"] = "1234"
book["감찬"] = "1111"   #자료 추가
book["순신"] = "5555"
print(book)
print(book["길동"])
print(book.keys())   # 딕셔너리 모든 키 볼수 있게
for key in sorted(book.keys()):
    print(key,book[key])
print(book.values())   # 딕셔너리 모든 값 볼수 있게
''' 딕셔너리 수정 삭제'''
''' del, .pop()'''
del book["길동"]
print(book)
print(book.pop("순신"))   # 순신의 값이 출력됨
print(book)
''' . clear() 모든항목 삭제'''

'''딕셔너리 이해'''
# item = {"커피":7,"펜":3,"종이컵":10,"우유":5,"콜라":4,"라면":11}
# print("판매 전 재고",item)
# sell = input("판매한 물건 입력")
# if sell in item:
#     item[sell] -= 1
# else:
#     print("판매 제품이 아닙니다.")
# print("판매 후 제고",item)
'''딕셔너리 반복'''
book1 = {"길동":"1234","감찬":"1111","순신":"5555"}  
for i in book1.keys():
    print(i)
for i in book1.values():
    print(i)
for k,v in book1.items():  # .items() key value 동시에 출력
    print("{}의 번호는 {} 입니다.".format(k,v))

''' 집합 '''
s=set()
s ={1,2,5}
s.add(10)
s.add(3)
print(s)
'''집합 삭제 '''
''' .discard()  .remove() .clear() 전체삭제'''
# Out:
# {'길동': '1234', '감찬': '1111', '순신': '5555'}
# 1234
# dict_keys(['길동', '감찬', '순신'])
# 감찬 1111
# 길동 1234
# 순신 5555
# dict_values(['1234', '1111', '5555'])
# {'감찬': '1111', '순신': '5555'}
# 5555
# {'감찬': '1111'}
# 길동
# 감찬
# 순신
# 1234
# 1111
# 5555
# 길동의 번호는 1234 입니다.
# 감찬의 번호는 1111 입니다.
# 순신의 번호는 5555 입니다.
# {1, 2, 3, 5, 10}
